# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/binary-classification).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll build a model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../input/dl-course-data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://i.imgur.com/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(256,activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256,activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1,activation="sigmoid")
])

# Check your answer
q_1.check()
# Out:
# Correct

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
# YOUR CODE HERE
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
q_2.solution()
# Out:
# Solution:
# ```python
#
# model.compile(
#     optimizer='adam',
#     loss='binary_crossentropy',
#     metrics=['binary_accuracy'],
# )
#
# ```

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# 175/175 [==============================] - 4s 15ms/step - loss: 0.5412 - binary_accuracy: 0.7385 - val_loss: 0.4306 - val_binary_accuracy: 0.8025
# Epoch 2/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.4338 - binary_accuracy: 0.7960 - val_loss: 0.3989 - val_binary_accuracy: 0.8180
# Epoch 3/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.4127 - binary_accuracy: 0.8049 - val_loss: 0.3902 - val_binary_accuracy: 0.8188
# Epoch 4/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.4037 - binary_accuracy: 0.8120 - val_loss: 0.3857 - val_binary_accuracy: 0.8194
# Epoch 5/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3980 - binary_accuracy: 0.8135 - val_loss: 0.3851 - val_binary_accuracy: 0.8238
# Epoch 6/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3952 - binary_accuracy: 0.8161 - val_loss: 0.3801 - val_binary_accuracy: 0.8246
# Epoch 7/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3880 - binary_accuracy: 0.8178 - val_loss: 0.3766 - val_binary_accuracy: 0.8256
# Epoch 8/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3855 - binary_accuracy: 0.8209 - val_loss: 0.3744 - val_binary_accuracy: 0.8307
# Epoch 9/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3858 - binary_accuracy: 0.8210 - val_loss: 0.3729 - val_binary_accuracy: 0.8293
# Epoch 10/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3774 - binary_accuracy: 0.8240 - val_loss: 0.3678 - val_binary_accuracy: 0.8307
# Epoch 11/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3772 - binary_accuracy: 0.8249 - val_loss: 0.3693 - val_binary_accuracy: 0.8292
# Epoch 12/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3756 - binary_accuracy: 0.8238 - val_loss: 0.3646 - val_binary_accuracy: 0.8342
# Epoch 13/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3717 - binary_accuracy: 0.8261 - val_loss: 0.3665 - val_binary_accuracy: 0.8313
# Epoch 14/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3684 - binary_accuracy: 0.8295 - val_loss: 0.3655 - val_binary_accuracy: 0.8328
# Epoch 15/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3676 - binary_accuracy: 0.8303 - val_loss: 0.3604 - val_binary_accuracy: 0.8356
# Epoch 16/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3690 - binary_accuracy: 0.8289 - val_loss: 0.3601 - val_binary_accuracy: 0.8361
# Epoch 17/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3646 - binary_accuracy: 0.8303 - val_loss: 0.3592 - val_binary_accuracy: 0.8364
# Epoch 18/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3636 - binary_accuracy: 0.8317 - val_loss: 0.3573 - val_binary_accuracy: 0.8358
# Epoch 19/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3665 - binary_accuracy: 0.8281 - val_loss: 0.3573 - val_binary_accuracy: 0.8369
# Epoch 20/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3610 - binary_accuracy: 0.8334 - val_loss: 0.3553 - val_binary_accuracy: 0.8370
# Epoch 21/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3616 - binary_accuracy: 0.8334 - val_loss: 0.3541 - val_binary_accuracy: 0.8395
# Epoch 22/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3603 - binary_accuracy: 0.8329 - val_loss: 0.3551 - val_binary_accuracy: 0.8372
# Epoch 23/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3571 - binary_accuracy: 0.8350 - val_loss: 0.3527 - val_binary_accuracy: 0.8381
# Epoch 24/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3535 - binary_accuracy: 0.8369 - val_loss: 0.3536 - val_binary_accuracy: 0.8384
# Epoch 25/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3550 - binary_accuracy: 0.8354 - val_loss: 0.3513 - val_binary_accuracy: 0.8395
# Epoch 26/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3514 - binary_accuracy: 0.8376 - val_loss: 0.3488 - val_binary_accuracy: 0.8408
# Epoch 27/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3488 - binary_accuracy: 0.8399 - val_loss: 0.3502 - val_binary_accuracy: 0.8406
# Epoch 28/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3518 - binary_accuracy: 0.8371 - val_loss: 0.3520 - val_binary_accuracy: 0.8392
# Epoch 29/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3495 - binary_accuracy: 0.8387 - val_loss: 0.3489 - val_binary_accuracy: 0.8421
# Epoch 30/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3460 - binary_accuracy: 0.8398 - val_loss: 0.3481 - val_binary_accuracy: 0.8415
# Epoch 31/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3510 - binary_accuracy: 0.8367 - val_loss: 0.3477 - val_binary_accuracy: 0.8426
# Epoch 32/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3456 - binary_accuracy: 0.8401 - val_loss: 0.3477 - val_binary_accuracy: 0.8417
# Epoch 33/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3449 - binary_accuracy: 0.8398 - val_loss: 0.3491 - val_binary_accuracy: 0.8409
# Epoch 34/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3443 - binary_accuracy: 0.8402 - val_loss: 0.3474 - val_binary_accuracy: 0.8415
# Epoch 35/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3429 - binary_accuracy: 0.8407 - val_loss: 0.3464 - val_binary_accuracy: 0.8426
# Epoch 36/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3417 - binary_accuracy: 0.8419 - val_loss: 0.3460 - val_binary_accuracy: 0.8427
# Epoch 37/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3459 - binary_accuracy: 0.8385 - val_loss: 0.3453 - val_binary_accuracy: 0.8435
# Epoch 38/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3392 - binary_accuracy: 0.8437 - val_loss: 0.3456 - val_binary_accuracy: 0.8436
# Epoch 39/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3397 - binary_accuracy: 0.8423 - val_loss: 0.3443 - val_binary_accuracy: 0.8446
# Epoch 40/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3376 - binary_accuracy: 0.8448 - val_loss: 0.3461 - val_binary_accuracy: 0.8420
# Epoch 41/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3402 - binary_accuracy: 0.8415 - val_loss: 0.3438 - val_binary_accuracy: 0.8442
# Epoch 42/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3362 - binary_accuracy: 0.8435 - val_loss: 0.3434 - val_binary_accuracy: 0.8441
# Epoch 43/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3377 - binary_accuracy: 0.8437 - val_loss: 0.3479 - val_binary_accuracy: 0.8428
# Epoch 44/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3355 - binary_accuracy: 0.8446 - val_loss: 0.3442 - val_binary_accuracy: 0.8442
# Epoch 45/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3344 - binary_accuracy: 0.8441 - val_loss: 0.3427 - val_binary_accuracy: 0.8443
# Epoch 46/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3345 - binary_accuracy: 0.8467 - val_loss: 0.3439 - val_binary_accuracy: 0.8438
# Epoch 47/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3332 - binary_accuracy: 0.8468 - val_loss: 0.3439 - val_binary_accuracy: 0.8446
# Epoch 48/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3309 - binary_accuracy: 0.8478 - val_loss: 0.3465 - val_binary_accuracy: 0.8429
# Epoch 49/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3321 - binary_accuracy: 0.8464 - val_loss: 0.3420 - val_binary_accuracy: 0.8445
# Epoch 50/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3319 - binary_accuracy: 0.8459 - val_loss: 0.3427 - val_binary_accuracy: 0.8465
# <AxesSubplot:title={'center':'Accuracy'}>

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!

# %% [markdown]
# # Conclusion #
#
# Congratulations! You've completed Kaggle's *Introduction to Deep Learning* course!
#
# With your new skills you're ready to take on more advanced applications like computer vision and sentiment classification. What would you like to do next?
#
# Why not try one of our *Getting Started* competitions?
#
# - Classify images with TPUs in [**Petals to the Metal**](https://www.kaggle.com/c/tpu-getting-started)
# - Create art with GANs in [**I'm Something of a Painter Myself**](https://www.kaggle.com/c/gan-getting-started)
# - Classify Tweets in [**Real or Not? NLP with Disaster Tweets**](https://www.kaggle.com/c/nlp-getting-started)
# - Detect contradiction and entailment in [**Contradictory, My Dear Watson**](https://www.kaggle.com/c/contradictory-my-dear-watson)
#
# Until next time, Kagglers!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [Learn Discussion forum](https://www.kaggle.com/learn-forum/191966) to chat with other Learners.*
